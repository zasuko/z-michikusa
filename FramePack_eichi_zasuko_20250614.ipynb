# %%
# FramePackのインストール
# !git clone https://github.com/lllyasviel/FramePack
# %cd FramePack
# !pip install -r requirements.txt

# FramePack-eichiのインストール
# !git clone https://github.com/git-ai-code/FramePack-eichi.git tmp
# !mv ./tmp/webui/* .
# !rm -rf ./tmp
# Out:
# Cloning into 'FramePack'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 84 (delta 22), reused 20 (delta 20), pack-reused 49 (from 1)
# Receiving objects: 100% (84/84), 49.23 KiB | 3.52 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# /content/FramePack
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 538.5 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 75.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 45.1 MB/s eta 0:00:00
# ...

# %%
# FramePack-eichiの実行
# !python endframe_ichi.py --share
# Out:
# HF_HOMEを設定: /content/FramePack/hf_download
# 2025-06-14 07:50:16.189558: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749887416.493324    9923 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749887416.575414    9923 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-14 07:50:17.227337: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# FramePack-oichiの実行
# !python oneframe_ichi.py --share
# Out:
# HF_HOMEを設定: /content/FramePack/hf_download
# RTX 40シリーズのGPUでFP8の高速化が可能です
# 2025-06-14 08:02:19.977379: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749888140.294607   12960 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749888140.373227   12960 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-14 08:02:21.022046: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
